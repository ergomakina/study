# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix
import statsmodels.api as sm

# %%
csv_in = 'winequality-red_modified-utf8.txt'

# %%
df = pd.read_csv(csv_in,delimiter='  ',skiprows=13,header=0,engine='python')
#print(df.info)
df2 = df.dropna(axis=0).reset_index(drop=True)
#print(df2.info)
#display(df2.head())
# Out:
# <bound method DataFrame.info of       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9        NaN
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 11              7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# 13              7.8             0.610         0.29             1.6      0.114
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 16              8.5             0.280         0.56             1.8      0.092
# 17              8.1             0.560         0.28             1.7      0.368
# 18              7.4             0.590         0.08             4.4      0.086
# 19              7.9             0.320         0.51             1.8      0.341
# 20              8.9             0.220         0.48             1.8      0.077
# 21              7.6             0.390         0.31             2.3      0.082
# 22              7.9             0.430         0.21             1.6      0.106
# 23              8.5             0.490         0.11             2.3      0.084
# 24              6.9             0.400         0.14             2.4      0.085
# 25              6.3             0.390         0.16             1.4      0.080
# 26              7.6             0.410         0.24             1.8      0.080
# 27              7.9             0.430         0.21             1.6      0.106
# 28              7.1             0.710         0.00             1.9      0.080
# 29              7.8             0.645         0.00             2.0      0.082
# ...             ...               ...          ...             ...        ...
# 1569            6.2             0.510         0.14             1.9      0.056
# 1570            6.4             0.360         0.53             2.2      0.230
# 1571            6.4             0.380         0.14             2.2      0.038
# 1572            7.3             0.690         0.32             2.2      0.069
# 1573            6.0             0.580         0.20             2.4      0.075
# 1574            5.6             0.310         0.78            13.9      0.074
# 1575            7.5             0.520         0.40             2.2      0.060
# 1576            8.0             0.300         0.63             1.6      0.081
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 9                    17.0                 102.0  0.99780  3.35       0.80
# 10                   15.0                  65.0  0.99590  3.28       0.54
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 12                   16.0                  59.0  0.99430  3.58       0.52
# 13                    9.0                  29.0  0.99740  3.26       1.56
# 14                   52.0                 145.0  0.99860  3.16       0.88
# 15                   51.0                 148.0  0.99860  3.17       0.93
# 16                   35.0                 103.0  0.99690  3.30       0.75
# 17                   16.0                  56.0  0.99680  3.11       1.28
# 18                    6.0                  29.0  0.99740  3.38       0.50
# 19                   17.0                  56.0  0.99690  3.04       1.08
# 20                   29.0                  60.0  0.99680  3.39       0.53
# 21                   23.0                  71.0  0.99820  3.52       0.65
# 22                   10.0                  37.0  0.99660  3.17       0.91
# 23                    9.0                  67.0  0.99680  3.17       0.53
# 24                   21.0                  40.0  0.99680  3.43       0.63
# 25                   11.0                  23.0  0.99550  3.34       0.56
# 26                    4.0                  11.0  0.99620  3.28       0.59
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 28                   14.0                  35.0  0.99720  3.47       0.55
# 29                    8.0                  16.0  0.99640  3.38       0.59
# ...                   ...                   ...      ...   ...        ...
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1571                 15.0                  25.0  0.99514  3.44       0.65
# 1572                 35.0                 104.0  0.99632  3.33       0.51
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1574                 23.0                  92.0  0.99677  3.39       0.48
# 1575                 12.0                  20.0  0.99474  3.26       0.64
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1577                 13.0                  27.0  0.99622  3.54       0.60
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# 6         9.4        5
# 7        10.0        7
# 8         9.5        7
# 9        10.5        5
# 10        9.2        5
# 11       10.5        5
# 12        9.9        5
# 13        9.1        5
# 14        9.2        5
# 15        9.2        5
# 16       10.5        7
# 17        9.3        5
# 18        9.0        4
# 19        9.2        6
# 20        9.4        6
# 21        9.7        5
# 22        9.5        5
# 23        9.4        5
# 24        9.7        6
# 25        9.3        5
# 26        9.5        5
# 27        9.5        5
# 28        9.4        5
# 29        9.8        6
# ...       ...      ...
# 1569     11.5        6
# 1570     12.4        6
# 1571     11.1        6
# 1572      9.5        5
# 1573     12.5        6
# 1574     10.5        6
# 1575     11.8        6
# 1576     10.8        6
# 1577     11.9        6
# 1578     11.3        6
# 1579     11.3        5
# 1580     11.9        6
# 1581     11.3        5
# 1582     11.9        5
# 1583      9.8        5
# 1584     11.6        7
# 1585     11.5        6
# 1586     11.4        6
# 1587     10.9        6
# 1588     12.8        6
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]>
# <bound method DataFrame.info of       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.760         0.04             2.3      0.092
# 2               7.4             0.660         0.00             1.8      0.075
# 3               7.9             0.600         0.06             1.6      0.069
# 4               7.3             0.650         0.00             1.2      0.065
# 5               7.8             0.580         0.02             2.0      0.073
# 6               7.5             0.500         0.36             6.1      0.071
# 7               6.7             0.580         0.08             1.8      0.097
# 8               7.5             0.500         0.36             6.1      0.071
# 9               5.6             0.615         0.00             1.6      0.089
# 10              7.8             0.610         0.29             1.6      0.114
# 11              8.9             0.620         0.18             3.8      0.176
# 12              8.9             0.620         0.19             3.9      0.170
# 13              8.5             0.280         0.56             1.8      0.092
# 14              8.1             0.560         0.28             1.7      0.368
# 15              7.4             0.590         0.08             4.4      0.086
# 16              7.9             0.320         0.51             1.8      0.341
# 17              8.9             0.220         0.48             1.8      0.077
# 18              7.6             0.390         0.31             2.3      0.082
# 19              7.9             0.430         0.21             1.6      0.106
# 20              8.5             0.490         0.11             2.3      0.084
# 21              6.9             0.400         0.14             2.4      0.085
# 22              6.3             0.390         0.16             1.4      0.080
# 23              7.6             0.410         0.24             1.8      0.080
# 24              7.9             0.430         0.21             1.6      0.106
# 25              7.1             0.710         0.00             1.9      0.080
# 26              7.8             0.645         0.00             2.0      0.082
# 27              6.7             0.675         0.07             2.4      0.089
# 28              6.9             0.685         0.00             2.5      0.105
# 29              8.3             0.655         0.12             2.3      0.083
# ...             ...               ...          ...             ...        ...
# 1566            6.2             0.510         0.14             1.9      0.056
# 1567            6.4             0.360         0.53             2.2      0.230
# 1568            6.4             0.380         0.14             2.2      0.038
# 1569            7.3             0.690         0.32             2.2      0.069
# 1570            6.0             0.580         0.20             2.4      0.075
# 1571            5.6             0.310         0.78            13.9      0.074
# 1572            7.5             0.520         0.40             2.2      0.060
# 1573            8.0             0.300         0.63             1.6      0.081
# 1574            6.2             0.700         0.15             5.1      0.076
# 1575            6.8             0.670         0.15             1.8      0.118
# 1576            6.2             0.560         0.09             1.7      0.053
# 1577            7.4             0.350         0.33             2.4      0.068
# 1578            6.2             0.560         0.09             1.7      0.053
# 1579            6.1             0.715         0.10             2.6      0.053
# 1580            6.2             0.460         0.29             2.1      0.074
# 1581            6.7             0.320         0.44             2.4      0.061
# 1582            7.2             0.390         0.44             2.6      0.066
# 1583            7.5             0.310         0.41             2.4      0.065
# 1584            5.8             0.610         0.11             1.8      0.066
# 1585            7.2             0.660         0.33             2.5      0.068
# 1586            6.6             0.725         0.20             7.8      0.073
# 1587            6.3             0.550         0.15             1.8      0.077
# 1588            5.4             0.740         0.09             1.7      0.089
# 1589            6.3             0.510         0.13             2.3      0.076
# 1590            6.8             0.620         0.08             1.9      0.068
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    15.0                  54.0  0.99700  3.26       0.65
# 2                    13.0                  40.0  0.99780  3.51       0.56
# 3                    15.0                  59.0  0.99640  3.30       0.46
# 4                    15.0                  21.0  0.99460  3.39       0.47
# 5                     9.0                  18.0  0.99680  3.36       0.57
# 6                    17.0                 102.0  0.99780  3.35       0.80
# 7                    15.0                  65.0  0.99590  3.28       0.54
# 8                    17.0                 102.0  0.99780  3.35       0.80
# 9                    16.0                  59.0  0.99430  3.58       0.52
# 10                    9.0                  29.0  0.99740  3.26       1.56
# 11                   52.0                 145.0  0.99860  3.16       0.88
# 12                   51.0                 148.0  0.99860  3.17       0.93
# 13                   35.0                 103.0  0.99690  3.30       0.75
# 14                   16.0                  56.0  0.99680  3.11       1.28
# 15                    6.0                  29.0  0.99740  3.38       0.50
# 16                   17.0                  56.0  0.99690  3.04       1.08
# 17                   29.0                  60.0  0.99680  3.39       0.53
# 18                   23.0                  71.0  0.99820  3.52       0.65
# 19                   10.0                  37.0  0.99660  3.17       0.91
# 20                    9.0                  67.0  0.99680  3.17       0.53
# 21                   21.0                  40.0  0.99680  3.43       0.63
# 22                   11.0                  23.0  0.99550  3.34       0.56
# 23                    4.0                  11.0  0.99620  3.28       0.59
# 24                   10.0                  37.0  0.99660  3.17       0.91
# 25                   14.0                  35.0  0.99720  3.47       0.55
# 26                    8.0                  16.0  0.99640  3.38       0.59
# 27                   17.0                  82.0  0.99580  3.35       0.54
# 28                   22.0                  37.0  0.99660  3.46       0.57
# 29                   15.0                 113.0  0.99660  3.17       0.66
# ...                   ...                   ...      ...   ...        ...
# 1566                 15.0                  34.0  0.99396  3.48       0.57
# 1567                 19.0                  35.0  0.99340  3.37       0.93
# 1568                 15.0                  25.0  0.99514  3.44       0.65
# 1569                 35.0                 104.0  0.99632  3.33       0.51
# 1570                 15.0                  50.0  0.99467  3.58       0.67
# 1571                 23.0                  92.0  0.99677  3.39       0.48
# 1572                 12.0                  20.0  0.99474  3.26       0.64
# 1573                 16.0                  29.0  0.99588  3.30       0.78
# 1574                 13.0                  27.0  0.99622  3.54       0.60
# 1575                 13.0                  20.0  0.99540  3.42       0.67
# 1576                 24.0                  32.0  0.99402  3.54       0.60
# 1577                  9.0                  26.0  0.99470  3.36       0.60
# 1578                 24.0                  32.0  0.99402  3.54       0.60
# 1579                 13.0                  27.0  0.99362  3.57       0.50
# 1580                 32.0                  98.0  0.99578  3.33       0.62
# 1581                 24.0                  34.0  0.99484  3.29       0.80
# 1582                 22.0                  48.0  0.99494  3.30       0.84
# 1583                 34.0                  60.0  0.99492  3.34       0.85
# 1584                 18.0                  28.0  0.99483  3.55       0.66
# 1585                 34.0                 102.0  0.99414  3.27       0.78
# 1586                 29.0                  79.0  0.99770  3.29       0.54
# 1587                 26.0                  35.0  0.99314  3.32       0.82
# 1588                 16.0                  26.0  0.99402  3.67       0.56
# 1589                 29.0                  40.0  0.99574  3.42       0.75
# 1590                 28.0                  38.0  0.99651  3.42       0.82
# 1591                 32.0                  44.0  0.99490  3.45       0.58
# 1592                 39.0                  51.0  0.99512  3.52       0.76
# 1593                 29.0                  40.0  0.99574  3.42       0.75
# 1594                 32.0                  44.0  0.99547  3.57       0.71
# 1595                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.4        5
# 3         9.4        5
# 4        10.0        7
# 5         9.5        7
# 6        10.5        5
# 7         9.2        5
# 8        10.5        5
# 9         9.9        5
# 10        9.1        5
# 11        9.2        5
# 12        9.2        5
# 13       10.5        7
# 14        9.3        5
# 15        9.0        4
# 16        9.2        6
# 17        9.4        6
# 18        9.7        5
# 19        9.5        5
# 20        9.4        5
# 21        9.7        6
# 22        9.3        5
# 23        9.5        5
# 24        9.5        5
# 25        9.4        5
# 26        9.8        6
# 27       10.1        5
# 28       10.6        6
# 29        9.8        5
# ...       ...      ...
# 1566     11.5        6
# 1567     12.4        6
# 1568     11.1        6
# 1569      9.5        5
# 1570     12.5        6
# 1571     10.5        6
# 1572     11.8        6
# 1573     10.8        6
# 1574     11.9        6
# 1575     11.3        6
# 1576     11.3        5
# 1577     11.9        6
# 1578     11.3        5
# 1579     11.9        5
# 1580      9.8        5
# 1581     11.6        7
# 1582     11.5        6
# 1583     11.4        6
# 1584     10.9        6
# 1585     12.8        6
# 1586      9.2        5
# 1587     11.6        6
# 1588     11.6        6
# 1589     11.0        6
# 1590      9.5        6
# 1591     10.5        5
# 1592     11.2        6
# 1593     11.0        6
# 1594     10.2        5
# 1595     11.0        6
#
# [1596 rows x 12 columns]>

# %%
X_all_org = df2.loc[:, 'fixed_acidity':'alcohol']  # explanatory variables
y = df2['quality']  # objective variable
print('X_all_org:', X_all_org.shape)
display(X_all_org.head())
print('y:', y.shape)
print(y.head())
# Out:
# X_all_org: (1596, 11)
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.76         0.04             2.3      0.092
# 2            7.4              0.66         0.00             1.8      0.075
# 3            7.9              0.60         0.06             1.6      0.069
# 4            7.3              0.65         0.00             1.2      0.065
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 15.0                  54.0   0.9970  3.26       0.65
# 2                 13.0                  40.0   0.9978  3.51       0.56
# 3                 15.0                  59.0   0.9964  3.30       0.46
# 4                 15.0                  21.0   0.9946  3.39       0.47
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.4
# 3      9.4
# 4     10.0
# y: (1596,)
# 0    5
# 1    5
# 2    5
# 3    5
# 4    7
# Name: quality, dtype: int64

# %%
X_all = pd.get_dummies(X_all_org, drop_first=True)
print('X_all:', X_all.shape)
display(X_all.head())
# Out:
# X_all: (1596, 11)
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.76         0.04             2.3      0.092
# 2            7.4              0.66         0.00             1.8      0.075
# 3            7.9              0.60         0.06             1.6      0.069
# 4            7.3              0.65         0.00             1.2      0.065
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 15.0                  54.0   0.9970  3.26       0.65
# 2                 13.0                  40.0   0.9978  3.51       0.56
# 3                 15.0                  59.0   0.9964  3.30       0.46
# 4                 15.0                  21.0   0.9946  3.39       0.47
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.4
# 3      9.4
# 4     10.0

# %%
corr_all = df2.corr(method='pearson')
display(corr_all)
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.254796     0.671376
# volatile_acidity          -0.254796          1.000000    -0.550864
# citric_acid                0.671376         -0.550864     1.000000
# residual_sugar             0.115231          0.001749     0.143933
# chlorides                  0.094037          0.061071     0.204452
# free_sulfur_dioxide       -0.154094         -0.011231    -0.060859
# total_sulfur_dioxide      -0.113752          0.076463     0.035440
# density                    0.668356          0.022282     0.365623
# pH                        -0.683007          0.234924    -0.542063
# sulphates                  0.183527         -0.261792     0.313457
# alcohol                   -0.061580         -0.202022     0.109363
# quality                    0.123354         -0.389718     0.225112
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.115231   0.094037            -0.154094
# volatile_acidity            0.001749   0.061071            -0.011231
# citric_acid                 0.143933   0.204452            -0.060859
# residual_sugar              1.000000   0.055469             0.187006
# chlorides                   0.055469   1.000000             0.005389
# free_sulfur_dioxide         0.187006   0.005389             1.000000
# total_sulfur_dioxide        0.203091   0.047337             0.667541
# density                     0.355759   0.200882            -0.021855
# pH                         -0.085640  -0.265166             0.071304
# sulphates                   0.005230   0.371164             0.051475
# alcohol                     0.041679  -0.221426            -0.069386
# quality                     0.013665  -0.128907            -0.050524
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.113752  0.668356 -0.683007   0.183527
# volatile_acidity                  0.076463  0.022282  0.234924  -0.261792
# citric_acid                       0.035440  0.365623 -0.542063   0.313457
# residual_sugar                    0.203091  0.355759 -0.085640   0.005230
# chlorides                         0.047337  0.200882 -0.265166   0.371164
# free_sulfur_dioxide               0.667541 -0.021855  0.071304   0.051475
# total_sulfur_dioxide              1.000000  0.071252 -0.065735   0.042895
# density                           0.071252  1.000000 -0.342146   0.148960
# pH                               -0.065735 -0.342146  1.000000  -0.196633
# sulphates                         0.042895  0.148960 -0.196633   1.000000
# alcohol                          -0.205651 -0.495957  0.206091   0.093188
# quality                          -0.185220 -0.174937 -0.057257   0.251463
#
#                        alcohol   quality
# fixed_acidity        -0.061580  0.123354
# volatile_acidity     -0.202022 -0.389718
# citric_acid           0.109363  0.225112
# residual_sugar        0.041679  0.013665
# chlorides            -0.221426 -0.128907
# free_sulfur_dioxide  -0.069386 -0.050524
# total_sulfur_dioxide -0.205651 -0.185220
# density              -0.495957 -0.174937
# pH                    0.206091 -0.057257
# sulphates             0.093188  0.251463
# alcohol               1.000000  0.476024
# quality               0.476024  1.000000

# %%
X_all_c = sm.add_constant(X_all)
model = sm.OLS(y, X_all_c)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     81.03
# Date:                Thu, 16 May 2019   Prob (F-statistic):          6.17e-145
# Time:                        21:04:43   Log-Likelihood:                -1567.6
# No. Observations:                1596   AIC:                             3159.
# Df Residuals:                    1584   BIC:                             3224.
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   21.6728     21.221      1.021      0.307     -19.951      63.297
# fixed_acidity            0.0245      0.026      0.942      0.346      -0.026       0.075
# volatile_acidity        -1.0814      0.121     -8.914      0.000      -1.319      -0.843
# citric_acid             -0.1836      0.147     -1.246      0.213      -0.473       0.105
# residual_sugar           0.0163      0.015      1.086      0.278      -0.013       0.046
# chlorides               -1.8757      0.420     -4.470      0.000      -2.699      -1.053
# free_sulfur_dioxide      0.0044      0.002      2.012      0.044       0.000       0.009
# total_sulfur_dioxide    -0.0033      0.001     -4.485      0.000      -0.005      -0.002
# density                -17.5773     21.660     -0.812      0.417     -60.063      24.908
# pH                      -0.4172      0.192     -2.173      0.030      -0.794      -0.041
# sulphates                0.9176      0.114      8.016      0.000       0.693       1.142
# alcohol                  0.2766      0.027     10.430      0.000       0.225       0.329
# ==============================================================================
# Omnibus:                       27.070   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.336
# Skew:                          -0.168   Prob(JB):                     1.74e-09
# Kurtosis:                       3.703   Cond. No.                     1.13e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# c:\python37\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
print('R2:', results.rsquared)#決定係数
print('Adj R2:', results.rsquared_adj)
# Out:
# R2: 0.3600832139208682
# Adj R2: 0.3556393473508742

# %%
from sklearn import preprocessing
X_scaled = preprocessing.scale(X_all)
y_scaled = preprocessing.scale(y)
model = sm.OLS(y_scaled, X_scaled)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     81.08
# Date:                Thu, 16 May 2019   Prob (F-statistic):          4.95e-145
# Time:                        21:08:24   Log-Likelihood:                -1908.4
# No. Observations:                1596   AIC:                             3839.
# Df Residuals:                    1585   BIC:                             3898.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0528      0.056      0.942      0.346      -0.057       0.163
# x2            -0.2394      0.027     -8.916      0.000      -0.292      -0.187
# x3            -0.0442      0.035     -1.247      0.213      -0.114       0.025
# x4             0.0285      0.026      1.087      0.277      -0.023       0.080
# x5            -0.1094      0.024     -4.471      0.000      -0.157      -0.061
# x6             0.0567      0.028      2.013      0.044       0.001       0.112
# x7            -0.1333      0.030     -4.486      0.000      -0.192      -0.075
# x8            -0.0411      0.051     -0.812      0.417      -0.140       0.058
# x9            -0.0797      0.037     -2.174      0.030      -0.152      -0.008
# x10            0.1927      0.024      8.019      0.000       0.146       0.240
# x11            0.3650      0.035     10.433      0.000       0.296       0.434
# ==============================================================================
# Omnibus:                       27.070   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.336
# Skew:                          -0.168   Prob(JB):                     1.74e-09
# Kurtosis:                       3.703   Cond. No.                         7.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import sys
my_libs_dir = '../'
if not my_libs_dir in sys.path:
    sys.path.append(my_libs_dir)  # add the path to my_lib directory 

# The following lines are needed to auto-reload my library file
# Without these lines, my library file is read only once and
# modifications of my library file are not reflected.
# %load_ext autoreload
# %autoreload 1
# %aimport my_libs.linear_reg
# import from my library file
from my_libs.linear_reg import step_aic_forward, calc_vifs

# %%
import statsmodels.formula.api as smf
dfX_scaled = pd.DataFrame(X_scaled, columns=X_all.columns)
dfy_scaled = pd.Series(y_scaled, name=y.name)
exog = list(dfX_scaled.columns)  # Initial set = all explanatory variables
endog = [dfy_scaled.name]  # Objective variables
df_scaled = pd.concat([dfX_scaled, dfy_scaled], axis=1)

results_aic=step_aic_forward(smf.ols, exog, endog, data=df_scaled)#変数増加法変数選択

print(results_aic.aic)
print(results_aic.model.exog_names)
print(results_aic.model.endog_names)
# Out:
# AIC: 4531.252, formula: quality ~ 1
# AIC: 4528.011, formula: quality ~ pH
# AIC: 4123.148, formula: quality ~ alcohol
# AIC: 4483.646, formula: quality ~ density
# AIC: 4270.337, formula: quality ~ volatile_acidity
# AIC: 4477.538, formula: quality ~ total_sulfur_dioxide
# AIC: 4506.508, formula: quality ~ chlorides
# AIC: 4450.253, formula: quality ~ citric_acid
# AIC: 4532.954, formula: quality ~ residual_sugar
# AIC: 4508.780, formula: quality ~ fixed_acidity
# AIC: 4529.172, formula: quality ~ free_sulfur_dioxide
# AIC: 4428.999, formula: quality ~ sulphates
# AIC: 4072.263, formula: quality ~ alcohol + pH
# AIC: 4114.882, formula: quality ~ alcohol + density
# AIC: 3928.074, formula: quality ~ alcohol + volatile_acidity
# AIC: 4108.632, formula: quality ~ alcohol + total_sulfur_dioxide
# AIC: 4123.949, formula: quality ~ alcohol + chlorides
# AIC: 4061.342, formula: quality ~ alcohol + citric_acid
# AIC: 4125.070, formula: quality ~ alcohol + residual_sugar
# AIC: 4076.123, formula: quality ~ alcohol + fixed_acidity
# AIC: 4124.514, formula: quality ~ alcohol + free_sulfur_dioxide
# AIC: 4033.266, formula: quality ~ alcohol + sulphates
# AIC: 3916.715, formula: quality ~ alcohol + volatile_acidity + pH
# AIC: 3925.723, formula: quality ~ alcohol + volatile_acidity + density
# AIC: 3915.671, formula: quality ~ alcohol + volatile_acidity + total_sulfur_dioxide
# AIC: 3929.233, formula: quality ~ alcohol + volatile_acidity + chlorides
# AIC: 3929.652, formula: quality ~ alcohol + volatile_acidity + citric_acid
# AIC: 3930.052, formula: quality ~ alcohol + volatile_acidity + residual_sugar
# AIC: 3917.297, formula: quality ~ alcohol + volatile_acidity + fixed_acidity
# AIC: 3928.580, formula: quality ~ alcohol + volatile_acidity + free_sulfur_dioxide
# AIC: 3885.199, formula: quality ~ alcohol + volatile_acidity + sulphates
# AIC: 3880.187, formula: quality ~ alcohol + volatile_acidity + sulphates + pH
# AIC: 3886.694, formula: quality ~ alcohol + volatile_acidity + sulphates + density
# AIC: 3868.077, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide
# AIC: 3869.818, formula: quality ~ alcohol + volatile_acidity + sulphates + chlorides
# AIC: 3886.594, formula: quality ~ alcohol + volatile_acidity + sulphates + citric_acid
# AIC: 3887.167, formula: quality ~ alcohol + volatile_acidity + sulphates + residual_sugar
# AIC: 3879.586, formula: quality ~ alcohol + volatile_acidity + sulphates + fixed_acidity
# AIC: 3884.626, formula: quality ~ alcohol + volatile_acidity + sulphates + free_sulfur_dioxide
# AIC: 3862.384, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + pH
# AIC: 3869.831, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + density
# AIC: 3851.195, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides
# AIC: 3869.892, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + citric_acid
# AIC: 3869.453, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + residual_sugar
# AIC: 3865.241, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + fixed_acidity
# AIC: 3866.897, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + free_sulfur_dioxide
# AIC: 3839.219, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH
# AIC: 3852.841, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + density
# AIC: 3852.835, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + citric_acid
# AIC: 3851.875, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + residual_sugar
# AIC: 3847.590, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + fixed_acidity
# AIC: 3850.249, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + free_sulfur_dioxide
# AIC: 3841.109, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + density
# AIC: 3839.254, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + citric_acid
# AIC: 3840.532, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + residual_sugar
# AIC: 3841.188, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + fixed_acidity
# AIC: 3835.476, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide
# AIC: 3837.399, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide + density
# AIC: 3836.304, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide + citric_acid
# AIC: 3837.071, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide + residual_sugar
# AIC: 3837.455, formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide + fixed_acidity
# The best formula: quality ~ alcohol + volatile_acidity + sulphates + total_sulfur_dioxide + chlorides + pH + free_sulfur_dioxide
# Minimum AIC: 3837.455
# 3835.4763012244853
# ['Intercept', 'alcohol', 'volatile_acidity', 'sulphates', 'total_sulfur_dioxide', 'chlorides', 'pH', 'free_sulfur_dioxide']
# quality

# %%
endogs = results_aic.model.endog_names
exogs = results_aic.model.exog_names.copy()
exogs.remove('Intercept')
print(exogs)  # debug
X_c = sm.add_constant(X_all[exogs])
vifs = calc_vifs(X_c, y)
display(vifs)
# Out:
# ['alcohol', 'volatile_acidity', 'sulphates', 'total_sulfur_dioxide', 'chlorides', 'pH', 'free_sulfur_dioxide']
# c:\python37\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                              VIF
# const                 618.539992
# alcohol                 1.220248
# volatile_acidity        1.242579
# sulphates               1.322258
# total_sulfur_dioxide    1.943518
# chlorides               1.333407
# pH                      1.255038
# free_sulfur_dioxide     1.882888

# %%
X_final_scaled = dfX_scaled[exogs]
model_final_scaled = sm.OLS(y_scaled, X_final_scaled)
results_final_scaled = model_final_scaled.fit()
print(results_final_scaled.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     127.1
# Date:                Thu, 16 May 2019   Prob (F-statistic):          1.48e-148
# Time:                        21:09:20   Log-Likelihood:                -1909.7
# No. Observations:                1596   AIC:                             3833.
# Df Residuals:                    1589   BIC:                             3871.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# alcohol                  0.3819      0.022     17.212      0.000       0.338       0.425
# volatile_acidity        -0.2235      0.022     -9.984      0.000      -0.267      -0.180
# sulphates                0.1856      0.023      8.036      0.000       0.140       0.231
# total_sulfur_dioxide    -0.1421      0.028     -5.074      0.000      -0.197      -0.087
# chlorides               -0.1177      0.023     -5.073      0.000      -0.163      -0.072
# pH                      -0.0922      0.023     -4.097      0.000      -0.136      -0.048
# free_sulfur_dioxide      0.0660      0.028      2.393      0.017       0.012       0.120
# ==============================================================================
# Omnibus:                       23.950   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.738
# Skew:                          -0.156   Prob(JB):                     2.86e-08
# Kurtosis:                       3.652   Cond. No.                         2.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(results_final_scaled.params)
# Out:
# alcohol                 0.381874
# volatile_acidity       -0.223534
# sulphates               0.185601
# total_sulfur_dioxide   -0.142075
# chlorides              -0.117664
# pH                     -0.092192
# free_sulfur_dioxide     0.065957
# dtype: float64

# %%
X_final_c = sm.add_constant(X_all[exogs])
model_final = sm.OLS(y, X_final_c)
results_final = model_final.fit()
print(results_final.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     127.1
# Date:                Thu, 16 May 2019   Prob (F-statistic):          1.85e-148
# Time:                        21:09:31   Log-Likelihood:                -1568.9
# No. Observations:                1596   AIC:                             3154.
# Df Residuals:                    1588   BIC:                             3197.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.4260      0.404     10.967      0.000       3.634       5.218
# alcohol                  0.2894      0.017     17.206      0.000       0.256       0.322
# volatile_acidity        -1.0098      0.101     -9.981      0.000      -1.208      -0.811
# sulphates                0.8840      0.110      8.034      0.000       0.668       1.100
# total_sulfur_dioxide    -0.0035      0.001     -5.072      0.000      -0.005      -0.002
# chlorides               -2.0181      0.398     -5.072      0.000      -2.799      -1.238
# pH                      -0.4825      0.118     -4.096      0.000      -0.714      -0.251
# free_sulfur_dioxide      0.0051      0.002      2.392      0.017       0.001       0.009
# ==============================================================================
# Omnibus:                       23.950   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.738
# Skew:                          -0.156   Prob(JB):                     2.86e-08
# Kurtosis:                       3.652   Cond. No.                     1.70e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print('R2:', results_final.rsquared)#最終 決定係数
print('Adj R2:', results_final.rsquared_adj)#自由度調整済み
# Out:
# R2: 0.3589972226304371
# Adj R2: 0.3561716436369945

# %%
print(results_final.params)
# Out:
# const                   4.426027
# alcohol                 0.289401
# volatile_acidity       -1.009819
# sulphates               0.884003
# total_sulfur_dioxide   -0.003487
# chlorides              -2.018132
# pH                     -0.482495
# free_sulfur_dioxide     0.005091
# dtype: float64

# %% [markdown]
# quality ~ 4.426 + 0.289401 * alcohol + 0.884003 * sulphates + 0.005091 * free_sulfur_dioxide + (-1.009819) * volatile_acidity + (-0.003487) * total_sulfur_dioxide + (-2.01832) * chlorides + (-0.482495) * pH
