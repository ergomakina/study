# %%
以下の操作を行うノートブック dm04-quiz.ipynb を作成し、プログラム全体を提出せよ。

提出方法
一連のノートブックを作成、Fileメニュー > Export Notebook As... >
Export Notebook to Executable Script から
Pythonファイルとしてダウンロード。VSCodeなどで開いて、
中身全体をコピーし(VSCodeならSelectionメニュー > Select All)、
MOOCsのフォームに貼り付けて提出。

ai-0102フォルダのpandas_training-utf8.csv(相対パスで指定)を読み込み、
FRESH列以降の各列の和を棒グラフとしてプロットする。
なお、Y軸ラベルは「Sum [m.u.]」とする。

※ 読み込んだデータフレームの内容を確認するなど
、棒グラフをプロットする以外の操作が含まれていても構わない。

# %%
import json
import pandas as pd
import folium

# %%
csv_in = '../ai-0102/pandas_training-utf8.csv'

# %%
df_pop = pd.read_csv(csv_in,delimiter=',',skiprows=0,header=0)
print(df_pop.shape)
display(df_pop.head())
display(df_pop.T.head())
print(df_pop.info())
# Out:
# (453, 8)
#                         Wholesale Customers Data Set Unnamed: 1 Unnamed: 2  \
# 0  https://archive.ics.uci.edu/ml/datasets/wholes...        NaN        NaN
# 1  Abreu, N. (2011). Analise do perfil do cliente...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  CHANNEL(販路): customers's Channel - Horeca (Hot...        NaN        NaN
# 4  REGION(地域): customers's Region - Lisbon, Oport...        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#                                                                             0    \
# Wholesale Customers Data Set  https://archive.ics.uci.edu/ml/datasets/wholes...
# ...

# %%
ser_sum = df_pop.loc[:,'FRESH':].sum()
print(ser_sum.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\miniconda3\envs\ds2019\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    4804             try:
# -> 4805                 return self._searchsorted_monotonic(label, side)
#    4806             except ValueError:
#
# ~\AppData\Local\Continuum\miniconda3\envs\ds2019\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    4764
# -> 4765         raise ValueError('index must be monotonic increasing or decreasing')
#    4766
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4ea760f92ca5> in <module>
# ...

# %%
plt.bar(ser_sum.index,ser_sum)
plt.ylbel
plt.show()
