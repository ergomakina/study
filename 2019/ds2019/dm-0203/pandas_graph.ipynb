# %% [markdown]
# ## Graph with Pandas

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Parameters

# %%
csv_in1 = '../ai-0102/2045_2017-utf8.csv'

# %% [markdown]
# ### Read CSV files

# %%
df1 = pd.read_csv(csv_in1, delimiter=',', skiprows=9, header=0)
df1['Date']=pd.to_datetime(df1['Date'], format="%Y/%m/%d")
print(df1.shape)
print(df1.info())
display(df1.head())
# Out:
# (201, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 7 columns):
# Date        201 non-null datetime64[ns]
# Open        201 non-null int64
# High        201 non-null int64
# Low         201 non-null int64
# Close       201 non-null int64
# Vol         201 non-null int64
# AdjClose    201 non-null int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 11.1 KB
# None
#         Date  Open  High   Low  Close  Vol  AdjClose
# 0 2017-01-04  9340  9340  9270   9270    6      9270
# 1 2017-01-05  9260  9340  9250   9260   22      9260
# 2 2017-01-06  9300  9380  9300   9380   69      9380
# 3 2017-01-10  9380  9390  9320   9370  465      9370
# 4 2017-01-11  9400  9520  9400   9490  233      9490

# %% [markdown]
# ### Add 25days moving average line

# %%
df1['25d_mov_ave'] = df1['AdjClose'].rolling(window=25).mean()
display(df1.head(30))
# Out:
#          Date  Open  High   Low  Close  Vol  AdjClose  25d_mov_ave
# 0  2017-01-04  9340  9340  9270   9270    6      9270          NaN
# 1  2017-01-05  9260  9340  9250   9260   22      9260          NaN
# 2  2017-01-06  9300  9380  9300   9380   69      9380          NaN
# 3  2017-01-10  9380  9390  9320   9370  465      9370          NaN
# 4  2017-01-11  9400  9520  9400   9490  233      9490          NaN
# 5  2017-01-12  9450  9550  9450   9550  542      9550          NaN
# 6  2017-01-13  9480  9480  9480   9480   10      9480          NaN
# 7  2017-01-16  9320  9320  9300   9300    4      9300          NaN
# 8  2017-01-23  9450  9450  9350   9350   19      9350          NaN
# 9  2017-01-25  9350  9350  9330   9330   24      9330          NaN
# 10 2017-01-27  9450  9450  9450   9450   20      9450          NaN
# 11 2017-01-30  9450  9450  9450   9450   25      9450          NaN
# 12 2017-01-31  9450  9460  9360   9360   35      9360          NaN
# 13 2017-02-01  9420  9420  9420   9420   10      9420          NaN
# 14 2017-02-03  9380  9500  9380   9500   17      9500          NaN
# 15 2017-02-06  9450  9520  9420   9520  569      9520          NaN
# 16 2017-02-07  9390  9470  9390   9470    2      9470          NaN
# 17 2017-02-08  9420  9500  9390   9500  204      9500          NaN
# 18 2017-02-09  9480  9500  9460   9500    5      9500          NaN
# 19 2017-02-10  9500  9630  9500   9630  348      9630          NaN
# 20 2017-02-13  9630  9630  9630   9630   32      9630          NaN
# 21 2017-02-14  9630  9640  9630   9640   42      9640          NaN
# 22 2017-02-15  9620  9670  9620   9620  153      9620          NaN
# 23 2017-02-16  9620  9620  9580   9580   16      9580          NaN
# 24 2017-02-17  9590  9620  9530   9540  284      9540       9463.6
# 25 2017-02-20  9580  9580  9580   9580    1      9580       9476.0
# 26 2017-02-21  9570  9570  9550   9550   58      9550       9487.6
# 27 2017-02-22  9600  9600  9560   9600   47      9600       9496.4
# 28 2017-02-23  9620  9650  9620   9650    3      9650       9507.6
# 29 2017-02-24  9600  9600  9600   9600   39      9600       9512.0

# %% [markdown]
# ### Line plot

# %%
df1.plot.line('Date', ['AdjClose', '25d_mov_ave'])

# %% [markdown]
# ### Scatter plot

# %%
df1.plot.scatter('High', 'Low')
